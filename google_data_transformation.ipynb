# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("Resources/Global_Mobility_Report.csv")
# Out:
# /Users/michaelboyce/opt/anaconda3/lib/python3.7/site-packages/IPython/core/interactiveshell.py:3063: DtypeWarning: Columns (3) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
df
# Out:
#        country_region_code        country_region       sub_region_1  \
# 0                       AE  United Arab Emirates                NaN
# 1                       AE  United Arab Emirates                NaN
# 2                       AE  United Arab Emirates                NaN
# 3                       AE  United Arab Emirates                NaN
# 4                       AE  United Arab Emirates                NaN
# ...                    ...                   ...                ...
# 441299                  ZW              Zimbabwe  Midlands Province
# 441300                  ZW              Zimbabwe  Midlands Province
# 441301                  ZW              Zimbabwe  Midlands Province
# 441302                  ZW              Zimbabwe  Midlands Province
# 441303                  ZW              Zimbabwe  Midlands Province
#
#        sub_region_2        date  \
# 0               NaN  2020-02-15
# 1               NaN  2020-02-16
# 2               NaN  2020-02-17
# ...

# %%
country_df = df[df['sub_region_1'].isnull()]
country_df
# Out:
#        country_region_code        country_region sub_region_1 sub_region_2  \
# 0                       AE  United Arab Emirates          NaN          NaN
# 1                       AE  United Arab Emirates          NaN          NaN
# 2                       AE  United Arab Emirates          NaN          NaN
# 3                       AE  United Arab Emirates          NaN          NaN
# 4                       AE  United Arab Emirates          NaN          NaN
# ...                    ...                   ...          ...          ...
# 440453                  ZW              Zimbabwe          NaN          NaN
# 440454                  ZW              Zimbabwe          NaN          NaN
# 440455                  ZW              Zimbabwe          NaN          NaN
# 440456                  ZW              Zimbabwe          NaN          NaN
# 440457                  ZW              Zimbabwe          NaN          NaN
#
# ...

# %%
country_df.to_csv('Cleaned/google_country_mobility_data.csv')
